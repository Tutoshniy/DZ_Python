# %% [markdown]
# ### Задание 1

# %%
from sympy import symbols, solve

x = symbols('x', real=True)
roots = solve(x**2 - 6*abs(x) + 8, x)
print(roots)
# Out:
# [-4, -2, 2, 4]

# %% [markdown]
# ### Задание 2

# %%
derivative = y.diff(x)
increasing_intervals = sp.solve(derivative > 0, x)
print("Интервалы, на которых функция возрастает:", increasing_intervals)

# %% [markdown]
# ### Задание 3

# %%
decreasing_intervals = sp.solve(derivative < 0, x)
print("Интервалы, на которых функция убывает:", decreasing_intervals)
